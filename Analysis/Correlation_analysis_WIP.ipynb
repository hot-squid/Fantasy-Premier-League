# %% [markdown]
# ## Correlation, partial correlation and multicollinerarity

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from imblearn.over_sampling import SMOTE
from scipy.stats import boxcox, zscore
import random

# %%
# Global parameters

# Current gameweek 
gameweek = 11

# Number of gameweeks to calculate rolling averages off 
rolling_number = 3

# %% [markdown]
# ## Collect available player data

# %%
# Initialize an empty list to store all individual, player gameweek data 
all_player_sep = []

# Loop through each gameweek
for i in range(1, gameweek + 1):  # Adjusting the range to start from 1 to gameweek
    # Read the CSV for the current gameweek
    x = pd.read_csv(rf'C:\Users\thoma\Code\Projects\Fantasy-Premier-League\Data\Players\Seperate_GW\GW_{i}.csv')
    
    # Append the current gameweek data to the list
    all_player_sep.append(x)

# Concatenate all dataframes in the list into a single dataframe
player_data = pd.concat(all_player_sep, axis=0, ignore_index=True)

# Drop unnamed column
player_data = player_data.drop(columns = ['Unnamed: 0'])

# %%
# Remove players who play less than 61 minutes in a game (i.e. they do not recieve their 2 points minimum for playoing this amount)
player_data = player_data[player_data['Minutes'] > 60].copy()

# %%
# Filter by Goalkeepers, Defenders, Midfielders, and Forwards
final_data_mids = player_data[player_data['Position'] == 'MID'].copy()
final_data_defs = player_data[player_data['Position'] == 'DEF'].copy()
final_data_gks = player_data[player_data['Position'] == 'GK'].copy()
final_data_fwds = player_data[player_data['Position'] == 'FWD'].copy()

# Combined data
data = [final_data_gks, final_data_defs, final_data_mids, final_data_fwds]

# %%
## Assess sample size of each category
print(f'GK:',final_data_gks.shape)
print(f'DEF:',final_data_defs.shape)
print(f'MID:',final_data_mids.shape)
print(f'FWD:',final_data_fwds.shape)
# Out:
# GK: (219, 33)
# DEF: (859, 33)
# MID: (952, 33)
# FWD: (218, 33)

# %% [markdown]
# ## Salient Predictors
#
# From my analysis on features, we want to focus on:
#
# - Goalkeepers: CLEAN SHEETS
# - Defenders: CLEAN SHEETS + goals
# - Midfielders: GOALS + assists
# - Forwards: GOALS

# %% [markdown]
# ## Goalkeepers

# %%
# Define correlation columns
correlations = ['Clean Sheets','Influence', 'Minutes', 'Goals', 'Assists', 'GW Points',
       'Goals Conceded', 'Penalties Saved', 'Penalties Missed', 'YC', 'RC',
       'Saves', 'Total Bonus Points', 'Total BPS', 'Creativity',
       'Threat', 'ICT Index', 'xG', 'xA', 'xGi', 'xGc', 'Transfers In GW',
       'Transfers Out GW', 'Gameweek','Difficulty']

# Sort the correlation matrix
corr = data[0][correlations].corr().sort_values(by='Clean Sheets', ascending=False)
corr.head(15)
# Out:
#                     Clean Sheets  Influence   Minutes  Goals   Assists  \
# Clean Sheets            1.000000   0.001367 -0.133180    NaN -0.059933
# GW Points               0.841103   0.372487 -0.156254    NaN  0.093204
# Total BPS               0.780782   0.445929 -0.123405    NaN  0.050851
# Total Bonus Points      0.672468   0.292074 -0.260277    NaN  0.012811
# Penalties Saved         0.183818   0.220646  0.009238    NaN -0.016075
# YC                      0.074161  -0.074262  0.021471    NaN -0.037361
# Influence               0.001367   1.000000  0.005577    NaN  0.068504
# ICT Index              -0.007833   0.993473  0.005097    NaN  0.117097
# Saves                  -0.016392   0.943758 -0.022068    NaN -0.015855
# Transfers In GW        -0.025933  -0.078325  0.014874    NaN  0.000652
# Gameweek               -0.027213  -0.028165 -0.021120    NaN  0.036749
# Threat                 -0.034443  -0.100140  0.004587    NaN -0.007982
# xG                     -0.034443  -0.100140  0.004587    NaN -0.007982
# Transfers Out GW       -0.049293  -0.033300 -0.005668    NaN -0.022371
# Assists                -0.059933   0.068504  0.007982    NaN  1.000000
#
#                     GW Points  Goals Conceded  Penalties Saved  \
# Clean Sheets         0.841103       -0.646412         0.183818
# GW Points            1.000000       -0.664103         0.445926
# Total BPS            0.911805       -0.736402         0.281609
# Total Bonus Points   0.821636       -0.443704         0.285417
# Penalties Saved      0.445926       -0.142854         1.000000
# YC                  -0.022894       -0.119205         0.075132
# Influence            0.372487        0.076930         0.220646
# ICT Index            0.364927        0.095419         0.214983
# Saves                0.304504        0.105584         0.044443
# Transfers In GW     -0.026375       -0.063559         0.001663
# Gameweek            -0.034459        0.033260        -0.011372
# Threat              -0.057026        0.035155        -0.009238
# xG                  -0.057026        0.035155        -0.009238
# Transfers Out GW    -0.036567        0.003925         0.033120
# Assists              0.093204        0.026010        -0.016075
#
#                     Penalties Missed        YC  ...    Threat  ICT Index  \
# Clean Sheets                     NaN  0.074161  ... -0.034443  -0.007833
# GW Points                        NaN -0.022894  ... -0.057026   0.364927
# Total BPS                        NaN -0.045187  ... -0.086861   0.432680
# Total Bonus Points               NaN  0.064057  ... -0.024252   0.287988
# Penalties Saved                  NaN  0.075132  ... -0.009238   0.214983
# YC                               NaN  1.000000  ... -0.021471  -0.080786
# Influence                        NaN -0.074262  ... -0.100140   0.993473
# ICT Index                        NaN -0.080786  ... -0.083281   1.000000
# Saves                            NaN -0.064544  ... -0.102653   0.931288
# Transfers In GW                  NaN  0.059640  ...  0.032759  -0.077988
# Gameweek                         NaN  0.028696  ... -0.000293  -0.026712
# Threat                           NaN -0.021471  ...  1.000000  -0.083281
# xG                               NaN -0.021471  ...  1.000000  -0.083281
# Transfers Out GW                 NaN  0.088507  ...  0.240097  -0.035130
# Assists                          NaN -0.037361  ... -0.007982   0.117097
#
#                           xG        xA       xGi       xGc  Transfers In GW  \
# Clean Sheets       -0.034443 -0.069543 -0.071224 -0.290621        -0.025933
# GW Points          -0.057026 -0.057723 -0.060552 -0.192663        -0.026375
# Total BPS          -0.086861 -0.054648 -0.058985 -0.226133        -0.030378
# Total Bonus Points -0.024252 -0.044179 -0.045367 -0.113798        -0.000609
# Penalties Saved    -0.009238 -0.018652 -0.019103  0.036343         0.001663
# YC                 -0.021471 -0.019617 -0.020684 -0.049908         0.059640
# Influence          -0.100140 -0.065710 -0.070708  0.414427        -0.078325
# ICT Index          -0.083281 -0.002837 -0.007035  0.404175        -0.077988
# Saves              -0.102653 -0.087648 -0.092755  0.410523        -0.062334
# Transfers In GW     0.032759  0.077155  0.078745 -0.181432         1.000000
# Gameweek           -0.000293  0.032914  0.032873  0.041629        -0.011469
# Threat              1.000000 -0.009262  0.041181 -0.046589         0.032759
# xG                  1.000000 -0.009262  0.041181 -0.046589         0.032759
# Transfers Out GW    0.240097 -0.008088  0.004028 -0.122744         0.404279
# Assists            -0.007982  0.072118  0.071658 -0.046534         0.000652
#
#                     Transfers Out GW  Gameweek  Difficulty
# Clean Sheets               -0.049293 -0.027213   -0.070897
# GW Points                  -0.036567 -0.034459   -0.058054
# Total BPS                  -0.060221 -0.040009   -0.048290
# Total Bonus Points          0.030924 -0.003572   -0.024643
# Penalties Saved             0.033120 -0.011372   -0.046261
# YC                          0.088507  0.028696    0.072457
# Influence                  -0.033300 -0.028165    0.160274
# ICT Index                  -0.035130 -0.026712    0.153887
# Saves                      -0.039355  0.004734    0.173167
# Transfers In GW             0.404279 -0.011469   -0.235937
# Gameweek                   -0.067632  1.000000    0.023802
# Threat                      0.240097 -0.000293    0.009071
# xG                          0.240097 -0.000293    0.009071
# Transfers Out GW            1.000000 -0.067632    0.093497
# Assists                    -0.022371  0.036749   -0.058556
#
# [15 rows x 25 columns]

# %% [markdown]
# ## Defenders

# %%
# Define correlation columns
correlations = ['Clean Sheets','Influence', 'Minutes', 'Goals', 'Assists', 'GW Points',
       'Goals Conceded', 'Penalties Saved', 'Penalties Missed', 'YC', 'RC',
       'Saves', 'Total Bonus Points', 'Total BPS', 'Creativity',
       'Threat', 'ICT Index', 'xG', 'xA', 'xGi', 'xGc', 'Transfers In GW',
       'Transfers Out GW', 'Gameweek','Difficulty']

# Sort the correlation matrix
corr = data[1][correlations].corr().sort_values(by='Clean Sheets', ascending=False)
corr.head(15)
# Out:
#                     Clean Sheets  Influence   Minutes     Goals   Assists  \
# Clean Sheets            1.000000  -0.022733 -0.044252 -0.028743 -0.027724
# GW Points               0.755845   0.420141  0.020640  0.462684  0.266254
# Total BPS               0.741986   0.398072  0.072532  0.262583  0.216237
# Total Bonus Points      0.422636   0.303869  0.041201  0.232771  0.163836
# Transfers Out GW        0.029328   0.044764  0.064060  0.048824 -0.034180
# xA                      0.014898   0.159587 -0.069221  0.024383  0.310502
# xGi                    -0.004790   0.269769 -0.000578  0.240183  0.257177
# Gameweek               -0.007676   0.061994  0.065366  0.031972 -0.005669
# Creativity             -0.020598   0.242725 -0.007397  0.070887  0.310951
# xG                     -0.021674   0.224536  0.068223  0.317313  0.056094
# Influence              -0.022733   1.000000  0.271489  0.649023  0.295749
# Transfers In GW        -0.027069   0.062577  0.063088  0.032899  0.069466
# Assists                -0.027724   0.295749  0.017199  0.000508  1.000000
# Goals                  -0.028743   0.649023  0.051358  1.000000  0.000508
# Threat                 -0.033375   0.391974  0.124319  0.478200  0.041435
#
#                     GW Points  Goals Conceded  Penalties Saved  \
# Clean Sheets         0.755845       -0.647349              NaN
# GW Points            1.000000       -0.609091              NaN
# Total BPS            0.893727       -0.703661              NaN
# Total Bonus Points   0.655749       -0.306072              NaN
# Transfers Out GW     0.052950       -0.072443              NaN
# xA                   0.142875        0.013322              NaN
# xGi                  0.196793        0.045391              NaN
# Gameweek             0.007484        0.011602              NaN
# Creativity           0.144263        0.010650              NaN
# xG                   0.137406        0.051276              NaN
# Influence            0.420141        0.073985              NaN
# Transfers In GW      0.022170        0.000153              NaN
# Assists              0.266254        0.068396              NaN
# Goals                0.462684        0.073759              NaN
# Threat               0.217020        0.051837              NaN
#
#                     Penalties Missed        YC  ...    Threat  ICT Index  \
# Clean Sheets                     NaN -0.051490  ... -0.033375  -0.035701
# GW Points                        NaN -0.206265  ...  0.217020   0.365922
# Total BPS                        NaN -0.212979  ...  0.142662   0.360338
# Total Bonus Points               NaN -0.081766  ...  0.095891   0.279870
# Transfers Out GW                 NaN  0.016676  ...  0.069357   0.117106
# xA                               NaN -0.056912  ...  0.111463   0.448885
# xGi                              NaN -0.032173  ...  0.541971   0.605590
# Gameweek                         NaN  0.002221  ...  0.010857   0.069850
# Creativity                       NaN -0.040417  ...  0.117556   0.680078
# xG                               NaN  0.011004  ...  0.659716   0.413644
# Influence                        NaN -0.113280  ...  0.391974   0.767385
# Transfers In GW                  NaN -0.002968  ...  0.132579   0.145881
# Assists                          NaN  0.005547  ...  0.041435   0.318232
# Goals                            NaN -0.030757  ...  0.478200   0.547832
# Threat                           NaN -0.024287  ...  1.000000   0.670927
#
#                           xG        xA       xGi       xGc  Transfers In GW  \
# Clean Sheets       -0.021674  0.014898 -0.004790 -0.289790        -0.027069
# GW Points           0.137406  0.142875  0.196793 -0.309598         0.022170
# Total BPS           0.037567  0.200016  0.166673 -0.383752         0.017004
# Total Bonus Points  0.025600  0.179169  0.143641 -0.181406         0.019150
# Transfers Out GW   -0.020572  0.114640  0.065929 -0.116152         0.346953
# xA                  0.014176  1.000000  0.711219 -0.075902         0.078710
# xGi                 0.712982  0.711219  1.000000 -0.054882         0.086519
# Gameweek            0.037657  0.059798  0.068408  0.032540        -0.005907
# Creativity          0.053048  0.632495  0.480834 -0.070271         0.116699
# xG                  1.000000  0.014176  0.712982 -0.002355         0.044554
# Influence           0.224536  0.159587  0.269769  0.093942         0.062577
# Transfers In GW     0.044554  0.078710  0.086519 -0.078680         1.000000
# Assists             0.056094  0.310502  0.257177  0.019140         0.069466
# Goals               0.317313  0.024383  0.240183  0.044173         0.032899
# Threat              0.659716  0.111463  0.541971 -0.019089         0.132579
#
#                     Transfers Out GW  Gameweek  Difficulty
# Clean Sheets                0.029328 -0.007676   -0.081007
# GW Points                   0.052950  0.007484   -0.119303
# Total BPS                   0.084932  0.024370   -0.151602
# Total Bonus Points          0.040892  0.000757   -0.043948
# Transfers Out GW            1.000000 -0.000691    0.064498
# xA                          0.114640  0.059798   -0.055506
# xGi                         0.065929  0.068408   -0.061757
# Gameweek                   -0.000691  1.000000    0.006723
# Creativity                  0.128596  0.068242   -0.082078
# xG                         -0.020572  0.037657   -0.032478
# Influence                   0.044764  0.061994   -0.050364
# Transfers In GW             0.346953 -0.005907   -0.130184
# Assists                    -0.034180 -0.005669   -0.083098
# Goals                       0.048824  0.031972   -0.002215
# Threat                      0.069357  0.010857   -0.050261
#
# [15 rows x 25 columns]

# %% [markdown]
# ## Midfielders

# %%
# Define correlation columns
correlations = ['Goals','Influence', 'Minutes', 'Clean Sheets', 'Assists', 'GW Points',
       'Goals Conceded', 'Penalties Saved', 'Penalties Missed', 'YC', 'RC',
       'Saves', 'Total Bonus Points', 'Total BPS', 'Creativity',
       'Threat', 'ICT Index', 'xG', 'xA', 'xGi', 'xGc', 'Transfers In GW',
       'Transfers Out GW', 'Gameweek','Difficulty']

# Sort the correlation matrix
corr = data[1][correlations].corr().sort_values(by='Goals', ascending=False)
corr.head(15)
# Out:
#                        Goals  Influence   Minutes  Clean Sheets   Assists  \
# Goals               1.000000   0.649023  0.051358     -0.028743  0.000508
# Influence           0.649023   1.000000  0.271489     -0.022733  0.295749
# ICT Index           0.547832   0.767385  0.179363     -0.035701  0.318232
# Threat              0.478200   0.391974  0.124319     -0.033375  0.041435
# GW Points           0.462684   0.420141  0.020640      0.755845  0.266254
# xG                  0.317313   0.224536  0.068223     -0.021674  0.056094
# Total BPS           0.262583   0.398072  0.072532      0.741986  0.216237
# xGi                 0.240183   0.269769 -0.000578     -0.004790  0.257177
# Total Bonus Points  0.232771   0.303869  0.041201      0.422636  0.163836
# Goals Conceded      0.073759   0.073985  0.042116     -0.647349  0.068396
# Creativity          0.070887   0.242725 -0.007397     -0.020598  0.310951
# Minutes             0.051358   0.271489  1.000000     -0.044252  0.017199
# Transfers Out GW    0.048824   0.044764  0.064060      0.029328 -0.034180
# xGc                 0.044173   0.093942  0.116720     -0.289790  0.019140
# Transfers In GW     0.032899   0.062577  0.063088     -0.027069  0.069466
#
#                     GW Points  Goals Conceded  Penalties Saved  \
# Goals                0.462684        0.073759              NaN
# Influence            0.420141        0.073985              NaN
# ICT Index            0.365922        0.063038              NaN
# Threat               0.217020        0.051837              NaN
# GW Points            1.000000       -0.609091              NaN
# xG                   0.137406        0.051276              NaN
# Total BPS            0.893727       -0.703661              NaN
# xGi                  0.196793        0.045391              NaN
# Total Bonus Points   0.655749       -0.306072              NaN
# Goals Conceded      -0.609091        1.000000              NaN
# Creativity           0.144263        0.010650              NaN
# Minutes              0.020640        0.042116              NaN
# Transfers Out GW     0.052950       -0.072443              NaN
# xGc                 -0.309598        0.582567              NaN
# Transfers In GW      0.022170        0.000153              NaN
#
#                     Penalties Missed        YC  ...    Threat  ICT Index  \
# Goals                            NaN -0.030757  ...  0.478200   0.547832
# Influence                        NaN -0.113280  ...  0.391974   0.767385
# ICT Index                        NaN -0.084760  ...  0.670927   1.000000
# Threat                           NaN -0.024287  ...  1.000000   0.670927
# GW Points                        NaN -0.206265  ...  0.217020   0.365922
# xG                               NaN  0.011004  ...  0.659716   0.413644
# Total BPS                        NaN -0.212979  ...  0.142662   0.360338
# xGi                              NaN -0.032173  ...  0.541971   0.605590
# Total Bonus Points               NaN -0.081766  ...  0.095891   0.279870
# Goals Conceded                   NaN  0.036157  ...  0.051837   0.063038
# Creativity                       NaN -0.040417  ...  0.117556   0.680078
# Minutes                          NaN -0.008270  ...  0.124319   0.179363
# Transfers Out GW                 NaN  0.016676  ...  0.069357   0.117106
# xGc                              NaN  0.002719  ... -0.019089   0.000107
# Transfers In GW                  NaN -0.002968  ...  0.132579   0.145881
#
#                           xG        xA       xGi       xGc  Transfers In GW  \
# Goals               0.317313  0.024383  0.240183  0.044173         0.032899
# Influence           0.224536  0.159587  0.269769  0.093942         0.062577
# ICT Index           0.413644  0.448885  0.605590  0.000107         0.145881
# Threat              0.659716  0.111463  0.541971 -0.019089         0.132579
# GW Points           0.137406  0.142875  0.196793 -0.309598         0.022170
# xG                  1.000000  0.014176  0.712982 -0.002355         0.044554
# Total BPS           0.037567  0.200016  0.166673 -0.383752         0.017004
# xGi                 0.712982  0.711219  1.000000 -0.054882         0.086519
# Total Bonus Points  0.025600  0.179169  0.143641 -0.181406         0.019150
# Goals Conceded      0.051276  0.013322  0.045391  0.582567         0.000153
# Creativity          0.053048  0.632495  0.480834 -0.070271         0.116699
# Minutes             0.068223 -0.069221 -0.000578  0.116720         0.063088
# Transfers Out GW   -0.020572  0.114640  0.065929 -0.116152         0.346953
# xGc                -0.002355 -0.075902 -0.054882  1.000000        -0.078680
# Transfers In GW     0.044554  0.078710  0.086519 -0.078680         1.000000
#
#                     Transfers Out GW  Gameweek  Difficulty
# Goals                       0.048824  0.031972   -0.002215
# Influence                   0.044764  0.061994   -0.050364
# ICT Index                   0.117106  0.069850   -0.088125
# Threat                      0.069357  0.010857   -0.050261
# GW Points                   0.052950  0.007484   -0.119303
# xG                         -0.020572  0.037657   -0.032478
# Total BPS                   0.084932  0.024370   -0.151602
# xGi                         0.065929  0.068408   -0.061757
# Total Bonus Points          0.040892  0.000757   -0.043948
# Goals Conceded             -0.072443  0.011602    0.172248
# Creativity                  0.128596  0.068242   -0.082078
# Minutes                     0.064060  0.065366   -0.006678
# Transfers Out GW            1.000000 -0.000691    0.064498
# xGc                        -0.116152  0.032540    0.239248
# Transfers In GW             0.346953 -0.005907   -0.130184
#
# [15 rows x 25 columns]

# %% [markdown]
# ## Forwards

# %%
# Define correlation columns
correlations = ['Goals','Influence', 'Minutes', 'Clean Sheets', 'Assists', 'GW Points',
       'Goals Conceded', 'Penalties Saved', 'Penalties Missed', 'YC', 'RC',
       'Saves', 'Total Bonus Points', 'Total BPS', 'Creativity',
       'Threat', 'ICT Index', 'xG', 'xA', 'xGi', 'xGc', 'Transfers In GW',
       'Transfers Out GW', 'Gameweek','Difficulty']

# Sort the correlation matrix
corr = data[2][correlations].corr().sort_values(by='Goals', ascending=False)
corr.head(15)
# Out:
#                        Goals  Influence   Minutes  Clean Sheets   Assists  \
# Goals               1.000000   0.805712  0.059245     -0.004392  0.032392
# GW Points           0.845850   0.875345  0.095178      0.134694  0.484845
# Influence           0.805712   1.000000  0.229540     -0.006979  0.406213
# Total BPS           0.735835   0.905418  0.219888     -0.010403  0.453674
# Total Bonus Points  0.710528   0.738433  0.142942     -0.020625  0.299828
# ICT Index           0.602691   0.800828  0.231775      0.013887  0.373823
# xG                  0.595684   0.482769  0.067926      0.015621  0.078013
# Threat              0.520349   0.496917  0.094537      0.018277  0.119432
# xGi                 0.519607   0.551715  0.130808      0.003158  0.269494
# Transfers Out GW    0.147364   0.130986  0.087464     -0.000712  0.112345
# Transfers In GW     0.145502   0.119033  0.090298     -0.014432  0.058622
# xA                  0.098901   0.315973  0.140595     -0.016425  0.376568
# Creativity          0.084298   0.362258  0.205563      0.019000  0.333857
# Minutes             0.059245   0.229540  1.000000     -0.047809  0.060178
# Assists             0.032392   0.406213  0.060178     -0.006286  1.000000
#
#                     GW Points  Goals Conceded  Penalties Saved  \
# Goals                0.845850       -0.010813              NaN
# GW Points            1.000000       -0.127996              NaN
# Influence            0.875345       -0.018268              NaN
# Total BPS            0.873635       -0.025634              NaN
# Total Bonus Points   0.840608       -0.060051              NaN
# ICT Index            0.704561       -0.079885              NaN
# xG                   0.519531       -0.051387              NaN
# Threat               0.498576       -0.083258              NaN
# xGi                  0.558803       -0.062696              NaN
# Transfers Out GW     0.190201       -0.024965              NaN
# Transfers In GW      0.157731       -0.042718              NaN
# xA                   0.276920       -0.040581              NaN
# Creativity           0.264848       -0.078449              NaN
# Minutes              0.095178        0.080496              NaN
# Assists              0.484845       -0.013818              NaN
#
#                     Penalties Missed        YC  ...    Threat  ICT Index  \
# Goals                      -0.016179 -0.061320  ...  0.520349   0.602691
# GW Points                  -0.044476 -0.181627  ...  0.498576   0.704561
# Influence                  -0.028155 -0.065837  ...  0.496917   0.800828
# Total BPS                  -0.048181 -0.167031  ...  0.429942   0.758192
# Total Bonus Points         -0.017140 -0.064588  ...  0.418353   0.614484
# ICT Index                   0.000797 -0.075222  ...  0.764372   1.000000
# xG                          0.156448 -0.076187  ...  0.708222   0.581459
# Threat                      0.034244 -0.070171  ...  1.000000   0.764372
# xGi                         0.131907 -0.065234  ...  0.674033   0.749971
# Transfers Out GW            0.002100 -0.047367  ...  0.170132   0.177046
# Transfers In GW             0.000592 -0.026349  ...  0.244508   0.218205
# xA                          0.017665 -0.010506  ...  0.218986   0.534925
# Creativity                 -0.005202 -0.036219  ...  0.257168   0.721526
# Minutes                    -0.019989 -0.010576  ...  0.094537   0.231775
# Assists                    -0.017147  0.012380  ...  0.119432   0.373823
#
#                           xG        xA       xGi       xGc  Transfers In GW  \
# Goals               0.595684  0.098901  0.519607 -0.002473         0.145502
# GW Points           0.519531  0.276920  0.558803 -0.076643         0.157731
# Influence           0.482769  0.315973  0.551715  0.001784         0.119033
# Total BPS           0.403679  0.377728  0.524183 -0.026513         0.109397
# Total Bonus Points  0.385204  0.252032  0.440173 -0.044090         0.147868
# ICT Index           0.581459  0.534925  0.749971 -0.114518         0.218205
# xG                  1.000000  0.097318  0.834425 -0.081988         0.209747
# Threat              0.708222  0.218986  0.674033 -0.131419         0.244508
# xGi                 0.834425  0.629707  1.000000 -0.126510         0.239896
# Transfers Out GW    0.185564  0.105350  0.203223 -0.047444         0.254880
# Transfers In GW     0.209747  0.137482  0.239896 -0.105868         1.000000
# xA                  0.097318  1.000000  0.629707 -0.112694         0.137482
# Creativity          0.152067  0.670294  0.489757 -0.126169         0.133828
# Minutes             0.067926  0.140595  0.130808  0.175088         0.090298
# Assists             0.078013  0.376568  0.269494 -0.040029         0.058622
#
#                     Transfers Out GW  Gameweek  Difficulty
# Goals                       0.147364 -0.018080   -0.097846
# GW Points                   0.190201 -0.023940   -0.144448
# Influence                   0.130986  0.002095   -0.136279
# Total BPS                   0.133401 -0.006781   -0.171122
# Total Bonus Points          0.170984 -0.011906   -0.106386
# ICT Index                   0.177046  0.006600   -0.201162
# xG                          0.185564  0.003094   -0.118543
# Threat                      0.170132  0.011129   -0.155031
# xGi                         0.203223 -0.017257   -0.172654
# Transfers Out GW            1.000000 -0.001203    0.082029
# Transfers In GW             0.254880  0.008637   -0.113940
# xA                          0.105350 -0.035535   -0.144703
# Creativity                  0.104205  0.003503   -0.168748
# Minutes                     0.087464 -0.003093   -0.035539
# Assists                     0.112345 -0.020901   -0.081488
#
# [15 rows x 25 columns]

# %% [markdown]
# Variables we are interested in doing further analysis on correlated with clean sheets and goals:
#
# ICT index
# Total BPS
# Influence
# Creativity
# xG
#
# We can control for other impact of variables (moderation and partial correlation techniques)

# %% [markdown]
# ## Multi-collineraity
#
# This occurs when 2 or more predictors share over 80% variance with each other.
# This could be indicated with an r^2 value of over 0.8. It means one could be predicted from the other to a substantial degree.
# This is problematic, as the parameters of the model (b) become interchangeable (and therefore unreliable) and the mathmatical techniques cannot discriminate between
# each predictor.
# One other test is the Variance Inflation Factor (VIF) = 1/ 1 r^2.
# If the number is greater than 5 this is moderate, if over 10 then severe multicollineraity.
